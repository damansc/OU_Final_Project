# %%
import pandas as pd
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', '.vscode', 'bls_ind_scraping.py', 'Untitled.ipynb']

# %%
os.chdir('../data')

# %%
os.listdir()
# Out:
# ['48-49']

# %%
emp = pd.read_excel('48-49/employment_tot.xlsx', skiprows=12, usecols=['Year', 'Period', 'Value'])

# %%
emp = emp[:-3]

# %%
newind = pd.date_range(start='01/01/2009', end='01/01/2019', freq='M')
emp['newind'] = newind
emp = emp[['newind', 'Value']]
emp.set_index(['newind'])

# %%
emp.plot(x='newind', y='Value')
